# %% [markdown]
# ## Utilisation de Jupyter
# ***
# Lien : https://www.youtube.com/watch?v=YuWZNV4BkkY <br>
# Date : 01-06-22

# %% [markdown]
# #### 1. Lancement du programme sans passer par le terminal : installation d'un package

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.4; however, version 22.1.1 is available.
# You should consider upgrading via the 'c:\Users\LRCOM\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# #### 2. Affichage des données avec Pandas (étape 2 du tuto non présenté : concerne les touches raccourcis)

# %%
import pandas as pd

# %%
df = pd.read_csv('data/titanic.csv')

# %%
pd.options.display.max_rows = 200 # Nombre de lignes à afficher
pd.options.display.max_columns = 50 # Nombre de colonnes à afficher

# %%
pd.options.display.max_colwidth = 20 # Largeur maximum des colonnes

# %%
pd.options.display.precision = 2 # Affichage des décimales dans un champ numérique

# %%
df.head(100)
# Out:
#     PassengerId  Survived  Pclass                 Name     Sex    Age  SibSp  \
# 0             1         0       3  Braund, Mr. Owen...    male  22.00      1
# 1             2         1       1  Cumings, Mrs. Jo...  female  38.00      1
# 2             3         1       3  Heikkinen, Miss....  female  26.00      0
# 3             4         1       1  Futrelle, Mrs. J...  female  35.00      1
# 4             5         0       3  Allen, Mr. Willi...    male  35.00      0
# 5             6         0       3     Moran, Mr. James    male    NaN      0
# 6             7         0       1  McCarthy, Mr. Ti...    male  54.00      0
# 7             8         0       3  Palsson, Master....    male   2.00      3
# 8             9         1       3  Johnson, Mrs. Os...  female  27.00      0
# 9            10         1       2  Nasser, Mrs. Nic...  female  14.00      1
# 10           11         1       3  Sandstrom, Miss....  female   4.00      1
# ...
