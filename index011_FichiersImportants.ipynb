# %%
"""
Data Science : la librairie pandas
Lien : https://www.youtube.com/watch?v=vmEHCJofslg

Récupération d'une partie d'un fichier dont la taille est conséquente

Éditeur : Laurent REYNAUD
Date : 30-06-2021
"""
# Out:
# "\nData Science : la librairie pandas\nLien : https://www.youtube.com/watch?v=vmEHCJofslg\n\nAccès aux statistiques du fichier avec l'instruction describe()\n(Nombre total de données, moyenne, 1er quartile....)\n\nÉditeur : Laurent REYNAUD\nDate : 30-06-2021\n"

# %%
import pandas as pd

# %%
# Récupération du fichier .csv par découpage de 5 lignues
for df_csv in pd.read_csv('data/modified.csv', chunksize=5) :
    print("\nDÉCOUPAGE DU FICHIER")
    print(df_csv)
# Out:
# 10  66     117       70       40
# 673  612     Haxorus  Dragon    NaN    540  76     147       90       60
# 674  613     Cubchoo     Ice    NaN    305  55      70       40       60
#
#      Sp. Def  Speed  Generation  Legendary
# 670       90     80           5      False
# 671       40     57           5      False
# 672       50     67           5      False
# 673       70     97           5      False
# 674       40     40           5      False
#
# DÉCOUPAGE DU FICHIER
#        #       Name  Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 675  614    Beartic     Ice       NaN    485   95     110       80       70
# 676  615  Cryogonal     Ice       NaN    485   70      50       30       95
# 677  616    Shelmet     Bug       NaN    305   50      40       85       40
# 678  617   Accelgor     Bug       NaN    495   80      70       40      100
# 679  618   Stunfisk  Ground  Electric    471  109      66       84       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...
